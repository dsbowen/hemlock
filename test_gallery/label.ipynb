# %%
from hemlock import create_test_app
from hemlock.questions import Label

app = create_test_app()

# %%
Label("Hello, world!").display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: lightgray;
#             }
#             input[type="radio"]:hover + label {
#                 background-color: lightgray;
#             }
#             input:checked + label {
#                 background-color: rgb(84, 84, 84);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: #BEBEBE;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="XND6tZ8GPT-card" class="card shadow my-4">
#     <div class="card-body">
#
#
#     <label class="w-100" for="XND6tZ8GPT">
#         Hello, world!
#     </label>
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#                 <div id="banner"></div>
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Label(
    """
    This is a really long label.

    It spans multiple lines
    *and uses markdown!*
    """
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: lightgray;
#             }
#             input[type="radio"]:hover + label {
#                 background-color: lightgray;
#             }
#             input:checked + label {
#                 background-color: rgb(84, 84, 84);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: #BEBEBE;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="vKXfi2F8Gc-card" class="card shadow my-4">
#     <div class="card-body">
#
#
#     <label class="w-100" for="vKXfi2F8Gc">
#         <p>This is a really long label.</p>
# It spans multiple lines <em>and uses markdown!</em>
#     </label>
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#                 <div id="banner"></div>
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>
