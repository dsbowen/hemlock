# %%
from hemlock import create_test_app
from hemlock.questions import Check

app = create_test_app()

# %%
Check(
    "What's your favorite ice cream flavor?",
    ["Chocolate", "Vanilla", "Strawberry"]
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="ebVvgoCSBw-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="ebVvgoCSBw">
#     <p>What's your favorite ice cream flavor?</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ebVvgoCSBw1" name="ebVvgoCSBw" class="form-check-input" type="radio" value="1">
#         <label class="form-check-label custom-check-label w-100" for="ebVvgoCSBw1">
#             Chocolate
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ebVvgoCSBw2" name="ebVvgoCSBw" class="form-check-input" type="radio" value="2">
#         <label class="form-check-label custom-check-label w-100" for="ebVvgoCSBw2">
#             Vanilla
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ebVvgoCSBw3" name="ebVvgoCSBw" class="form-check-input" type="radio" value="3">
#         <label class="form-check-label custom-check-label w-100" for="ebVvgoCSBw3">
#             Strawberry
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "Which ice cream flavors do you like?",
    ["Chocolate", "Vanilla", "Strawberry"],
    multiple=True
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="pzR2pX5NCG-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="pzR2pX5NCG">
#     <p>Which ice cream flavors do you like?</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="pzR2pX5NCG1" name="pzR2pX5NCG" class="form-check-input" type="checkbox" value="1">
#         <label class="form-check-label custom-check-label w-100" for="pzR2pX5NCG1">
#             Chocolate
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="pzR2pX5NCG2" name="pzR2pX5NCG" class="form-check-input" type="checkbox" value="2">
#         <label class="form-check-label custom-check-label w-100" for="pzR2pX5NCG2">
#             Vanilla
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="pzR2pX5NCG3" name="pzR2pX5NCG" class="form-check-input" type="checkbox" value="3">
#         <label class="form-check-label custom-check-label w-100" for="pzR2pX5NCG3">
#             Strawberry
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
levels_of_agreement = ("Disagree", "Neither agree nor disagree", "Agree")
Check(
    "How much do you agree?",
    [(i, level) for i, level in enumerate(levels_of_agreement)]
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="dktD58J9pA-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="dktD58J9pA">
#     <p>How much do you agree?</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="dktD58J9pA1" name="dktD58J9pA" class="form-check-input" type="radio" value="1">
#         <label class="form-check-label custom-check-label w-100" for="dktD58J9pA1">
#             Disagree
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="dktD58J9pA2" name="dktD58J9pA" class="form-check-input" type="radio" value="2">
#         <label class="form-check-label custom-check-label w-100" for="dktD58J9pA2">
#             Neither agree nor disagree
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="dktD58J9pA3" name="dktD58J9pA" class="form-check-input" type="radio" value="3">
#         <label class="form-check-label custom-check-label w-100" for="dktD58J9pA3">
#             Agree
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "This question has disabled choices.",
    ["Enabled", {"value": "Disabled", "disabled": True}]
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="JZI7miOuim-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="JZI7miOuim">
#     <p>This question has disabled choices.</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="JZI7miOuim1" name="JZI7miOuim" class="form-check-input" type="radio" value="1">
#         <label class="form-check-label custom-check-label w-100" for="JZI7miOuim1">
#             Enabled
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="JZI7miOuim2" name="JZI7miOuim" class="form-check-input" type="radio" value="2" disabled>
#         <label class="form-check-label custom-check-label w-100" for="JZI7miOuim2">
#             Disabled
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "This question has a default response.",
    [0, 1, 2],
    default=1
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="jWqaHKfuoi-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="jWqaHKfuoi">
#     <p>This question has a default response.</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="jWqaHKfuoi1" name="jWqaHKfuoi" class="form-check-input" type="radio" value="1">
#         <label class="form-check-label custom-check-label w-100" for="jWqaHKfuoi1">
#             0
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="jWqaHKfuoi2" name="jWqaHKfuoi" class="form-check-input" type="radio" value="2" checked>
#         <label class="form-check-label custom-check-label w-100" for="jWqaHKfuoi2">
#             1
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="jWqaHKfuoi3" name="jWqaHKfuoi" class="form-check-input" type="radio" value="3">
#         <label class="form-check-label custom-check-label w-100" for="jWqaHKfuoi3">
#             2
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "This question has multiple defaults.",
    [0, 1, 2],
    multiple=True,
    default=[1, 2]
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="ab6QxZfIcr-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="ab6QxZfIcr">
#     <p>This question has multiple defaults.</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ab6QxZfIcr1" name="ab6QxZfIcr" class="form-check-input" type="checkbox" value="1">
#         <label class="form-check-label custom-check-label w-100" for="ab6QxZfIcr1">
#             0
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ab6QxZfIcr2" name="ab6QxZfIcr" class="form-check-input" type="checkbox" value="2" checked>
#         <label class="form-check-label custom-check-label w-100" for="ab6QxZfIcr2">
#             1
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check">
#         <input id="ab6QxZfIcr3" name="ab6QxZfIcr" class="form-check-input" type="checkbox" value="3" checked>
#         <label class="form-check-label custom-check-label w-100" for="ab6QxZfIcr3">
#             2
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "This check uses inline choices.",
    [0, 1, 2],
    inline=True
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="wQjCeLvYaw-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="wQjCeLvYaw">
#     <p>This check uses inline choices.</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-check-inline">
#         <input id="wQjCeLvYaw1" name="wQjCeLvYaw" class="form-check-input" type="radio" value="1">
#         <label class="form-check-label custom-check-label w-100" for="wQjCeLvYaw1">
#             0
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-check-inline">
#         <input id="wQjCeLvYaw2" name="wQjCeLvYaw" class="form-check-input" type="radio" value="2">
#         <label class="form-check-label custom-check-label w-100" for="wQjCeLvYaw2">
#             1
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-check-inline">
#         <input id="wQjCeLvYaw3" name="wQjCeLvYaw" class="form-check-input" type="radio" value="3">
#         <label class="form-check-label custom-check-label w-100" for="wQjCeLvYaw3">
#             2
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
Check(
    "This check uses switch choices.",
    [0, 1, 2],
    switch=True,
).display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="f7xit4GOCR-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="f7xit4GOCR">
#     <p>This check uses switch choices.</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-switch">
#         <input id="f7xit4GOCR1" name="f7xit4GOCR" class="form-check-input" type="checkbox" value="1">
#         <label class="form-check-label custom-check-label w-100" for="f7xit4GOCR1">
#             0
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-switch">
#         <input id="f7xit4GOCR2" name="f7xit4GOCR" class="form-check-input" type="checkbox" value="2">
#         <label class="form-check-label custom-check-label w-100" for="f7xit4GOCR2">
#             1
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-switch">
#         <input id="f7xit4GOCR3" name="f7xit4GOCR" class="form-check-input" type="checkbox" value="3">
#         <label class="form-check-label custom-check-label w-100" for="f7xit4GOCR3">
#             2
#         </label>
#     </div>
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>

# %%
check = Check(
    "Which survey software is better?",
    ["Hemlock", "Qualtrics"],
    form_text="Hint: There is a correct answer.",
    switch=True,
    inline=True
)
check.raw_response = "Hemlock"
check.set_is_valid(True)
check.feedback = "Yup!"
check.display()
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <link rel="shortcut icon" href="https://dsbowen.gitlab.io/hemlock/_static/favicon.png">
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.0/dist/css/bootstrap.min.css" integrity="sha384-KyZXEAg3QhqLMpG8r+8fhAXLRk2vvoC2f3B09zVXn8CA5QIVfZOJ3BCsw2P0p/We" crossorigin="anonymous"><link href="https://fonts.googleapis.com/css?family=Josefin+Sans&display=swap" rel="stylesheet">
#
#
#
#         <style>
#             input[type="checkbox"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input[type="radio"]:hover + label {
#                 background-color: rgb(224,224,224);
#             }
#             input:checked + label {
#                 background-color: rgb(206, 206, 206);
#             }
#             input[type="checkbox"]:checked:hover + label {
#                 background-color: gainsboro;
#             }
#             .custom-check-label {
#                 padding-left: 3px;
#                 padding-right: 3px;
#                 border-radius: 3px;
#                 background-clip: padding-box;
#             }
#             .loading {
#                 display: none;
#                 position: fixed;
#                 align-items: center;
#                 justify-content: center;
#                 background: rgba(0, 0, 0, .2);
#                 height: 100vh;
#                 width: 100%;
#                 top: 0;
#                 left: 0;
#                 z-index: 9999;
#             }
#             /* @media (prefers-color-scheme: dark) {
#                 body {
#                     background-color: black;
#                     color: white;
#                 }
#                 .card {
#                     background-color: #4A4A4A;
#                 }
#             } */
#         </style>
#
#         <style>
#             body {
#                 background-color: inherit;
#                 color: inherit;
#             }
#         </style>
#
#
#     </head>
#     <body>
#         <div class="loading">
#             <div class="spinner-border" role="status">
#                 <span class="visually-hidden">Loading...</span>
#             </div>
#         </div>
#
#
#
#
#         <div class="container d-flex align-items-center" style="padding-bottom:20px;">
#             <form method="POST" class="w-100" enctype="multipart/form-data">
#
#
#                     <div id="E2AnCenfBe-card" class="card shadow my-4">
#     <div class="card-body">
#
#
# <label class="form-label w-100" for="E2AnCenfBe">
#     <p>Which survey software is better?</p>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-check-inline form-switch">
#         <input id="E2AnCenfBe1" name="E2AnCenfBe" class="form-check-input" type="radio" value="1" checked>
#         <label class="form-check-label custom-check-label w-100" for="E2AnCenfBe1">
#             Hemlock
#         </label>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="form-check form-check-inline form-switch">
#         <input id="E2AnCenfBe2" name="E2AnCenfBe" class="form-check-input" type="radio" value="2">
#         <label class="form-check-label custom-check-label w-100" for="E2AnCenfBe2">
#             Qualtrics
#         </label>
#     </div>
#
#
#
# <div class="valid-feedback" style="display:block;">
#     Yup!
# </div>
#
#
# <div class="form-text">
#     Hint: There is a correct answer.
# </div>
#
#
#     </div>
# </div>
#
#
#
#
#                 <p style="clear:both;"><br></p>
#
#
#
#             </form>
#         </div>
#
#         <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script><script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#
#
#
#         <script>
#             $("form").submit( function(e) {
#                 $(".loading").css("display", "flex");
#             });
#         </script>
#
#     </body>
# </html>
